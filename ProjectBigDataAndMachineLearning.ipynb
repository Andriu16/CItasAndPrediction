# %% [markdown]
# <a href="https://colab.research.google.com/github/Andriu16/CItasAndPrediction/blob/main/ProjectBigDataAndMachineLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/heart.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
def sano_enfermo(fila):
    if int(fila['target']) == 0:
        return 'sano'
    else:
        return 'enfermo'




df['estado'] = df.apply(sano_enfermo, axis=1)
df.head(20)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    52    1   0       125   212    0        1      168      0      1.0
# 1    53    1   0       140   203    1        0      155      1      3.1
# 2    70    1   0       145   174    0        1      125      1      2.6
# 3    61    1   0       148   203    0        1      161      0      0.0
# 4    62    0   0       138   294    1        1      106      0      1.9
# 5    58    0   0       100   248    0        0      122      0      1.0
# 6    58    1   0       114   318    0        2      140      0      4.4
# 7    55    1   0       160   289    0        0      145      1      0.8
# 8    46    1   0       120   249    0        0      144      0      0.8
# 9    54    1   0       122   286    0        0      116      1      3.2
# 10   71    0   0       112   149    0        1      125      0      1.6
# 11   43    0   0       132   341    1        0      136      1      3.0
# ...

# %%
resultado = dict(zip(df['target']. unique(), df['estado'].unique()))
resultado
# Out:
# {0: 'sano', 1: 'enfermo'}

# %%
from sklearn.model_selection import train_test_split

# %%
  X=df[['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal']]
  y = df['target']

  X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, test_size=0.20)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=3,metric='manhattan')
knn.fit(X_train ,y_train)
# Out:
# KNeighborsClassifier(metric='manhattan', n_neighbors=3)

# %%
estimacion=knn.score(X_test,y_test)
print(f'La efectividad con el modelo de kNN es de {estimacion} ')
# Out:
# La efectividad con el modelo de kNN es de 0.9360902255639098

# %%
estimacion_prueba=knn.score(X_test,y_test)
estimacion_entrenamiento=knn.score(X_train,y_train)

print(f'La efectividad con estimacion prueba con el modelo de kNN es de {estimacion_prueba}, y con la data de entrenamiento es {estimacion_entrenamiento} ')
# Out:
# La efectividad con estimacion prueba con el modelo de kNN es de 0.9360902255639098, y con la data de entrenamiento es 0.9962335216572504

# %%
prediccion = knn.predict([[40,0,4,123,250,2,1,200,0,1.1,2,0,1]])
resultado[prediccion[0]]
# Out:
# 'enfermo'

# %%
# !pip install Flask
# !pip install pyngrok
from flask import Flask, request, jsonify
from pyngrok import ngrok
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
app = Flask(__name__)

# %%
# !ngrok authtoken 2oOegtXOtqs2wssLtsp1E61DLSx_4M3NoGnJ6dhy7WcFGU4oC
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
@app.route('/')
def index():
    return "Bienvenido al servicio de predicción de salud con KNN."

# %%
@app.route('/predict', methods=['POST'])
def predict():
    data = request.json
    features = [data['age'], data['sex'], data['cp'], data['trestbps'],
                data['chol'], data['fbs'], data['restecg'], data['thalach'],
                data['exang'], data['oldpeak'], data['slope'], data['ca'], data['thal']]

    # Realizar la predicción
    prediccion = knn.predict([features])[0]

    # Mapear el resultado a una respuesta más amigable
    resultado = 'sano' if prediccion == 1 else 'enfermo'

    # Devolver la respuesta en formato JSON
    return jsonify({"prediccion":resultado})

# %%
if __name__ == '__main__':
    # Iniciar ngrok
    url = ngrok.connect(5000, bind_tls=False)
    print('Public URL:', url)
    app.run(port=5000)
# Out:
# Public URL: NgrokTunnel: "http://1eb8-34-138-187-42.ngrok-free.app" -> "http://localhost:5000"
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [04/Dec/2024 18:37:02] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [04/Dec/2024 18:37:42] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [04/Dec/2024 18:42:25] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [04/Dec/2024 18:43:31] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [04/Dec/2024 18:43:52] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [04/Dec/2024 18:44:22] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [04/Dec/2024 18:45:23] "POST /predict HTTP/1.1" 200 -
# ...
